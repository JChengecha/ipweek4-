# %% [markdown]
# #  Autolib: Electric Car Shairing Service

# %% [markdown]
# ## Research Question
# We are presented with a research question whereby we are to identify the most popular hour of the day for picking up a shared electric car (Bluecar) in the city of Paris over the month of April 2018.
#
# Futher to this, there are bonus questions:
# - What is the most popular hour for returning cars?
# - What station is the most popular?
#    - Overall?
#    - At the most popular picking hour?
# - What postal code is the most popular for picking up Blue cars? Does the most popular station belong to that postal code?
#     - Overall?
#     - At the most popular picking hour?
#
# - Do the results change if you consider Utilib and Utilib 1.4 instead of Blue cars?
#
#
#  The following is the link to the data and its description:
#  [http://bit.ly/autolib_dataset] and [Link](https://drive.google.com/a/moringaschool.com/file/d/13DXF2CFWQLeYxxHFekng8HJnH_jtbfpN/view?usp=sharing)

# %% [markdown]
# ### Importing the necessary libraries for the project

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading and previewing the data

# %%
#url=http://bit.ly/autolib_dataset

df=pd.read_csv('http://bit.ly/autolib_dataset')

# %%
df.head(10)
# Out:
#                               Address  Cars  Bluecar counter  Utilib counter  \
# 0                 2 Avenue de Suffren     0                0               0
# 1           145 Rue Raymond Losserand     6                6               0
# 2    2 Avenue John Fitzgerald Kennedy     3                3               0
# 3              51 Rue Eug̬ne Oudin̩     3                3               1
# 4  6 avenue de la Porte de Champerret     3                3               0
# 5                8 Boulevard Voltaire     0                0               0
# 6                      37 rue Leblanc     0                0               0
# 7         17 Rue des Luaps Prolong̩e     3                3               1
# 8               34 avenue Jean Moulin     1                1               0
# 9        41 boulevard de Rochechouart     6                6               0
#
#    Utilib 1.4 counter  Charge Slots Charging Status        City  \
# 0                   0             0     nonexistent       Paris
# 1                   0             0     operational       Paris
# 2                   2             0     operational  Le Bourget
# 3                   0             1     operational       Paris
# 4                   0             0     nonexistent       Paris
# 5                   0             0     nonexistent       Paris
# 6                   0             0     nonexistent       Paris
# 7                   0             0     nonexistent    Nanterre
# 8                   0             0     nonexistent       Paris
# 9                   0             0     nonexistent       Paris
#
#                                    Displayed comment  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  Station en parking (niv -1), acc̬s 37 rue Leb...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                   ID  ... Scheduled at Slots  Station type  \
# 0                    paris-suffren-2  ...          NaN     2       station
# 1         paris-raymondlosserand-145  ...          NaN     0       station
# 2  lebourget-johnfitzgeraldkennedy-2  ...          NaN     1       station
# 3              paris-eugeneoudine-51  ...          NaN     2       station
# 4          paris-portedechamperret-6  ...          NaN     3       station
# 5                   paris-voltaire-8  ...          NaN     4       station
# 6      paris-citroencevennes-parking  ...          NaN     0       station
# 7                  nanterre-luaps-17  ...          NaN     0       station
# 8                paris-jeanmoulin-34  ...          NaN     4       station
# 9               paris-anvers-parking  ...          NaN     0       station
#
#    Status Subscription status  year  month day hour minute
# 0      ok         nonexistent  2018      4   8   11     43
# 1      ok         nonexistent  2018      4   6    7     24
# 2      ok         nonexistent  2018      4   3   20     14
# 3      ok         nonexistent  2018      4   4    4     37
# 4      ok         nonexistent  2018      4   8   17     23
# 5      ok         nonexistent  2018      4   6    7      2
# 6  closed         nonexistent  2018      4   8   18     20
# 7      ok         nonexistent  2018      4   4   22     13
# 8      ok         nonexistent  2018      4   2   22     58
# 9      ok         nonexistent  2018      4   4   15      2
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Access information on the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   Displayed comment    111 non-null    object
#  9   ID                   5000 non-null   object
#  10  Kind                 5000 non-null   object
#  11  Geo point            5000 non-null   object
#  12  Postal code          5000 non-null   int64
#  13  Public name          5000 non-null   object
#  14  Rental status        5000 non-null   object
#  15  Scheduled at         47 non-null     object
#  16  Slots                5000 non-null   int64
#  17  Station type         5000 non-null   object
#  18  Status               5000 non-null   object
#  19  Subscription status  5000 non-null   object
#  20  year                 5000 non-null   int64
#  21  month                5000 non-null   int64
#  22  day                  5000 non-null   int64
#  23  hour                 5000 non-null   int64
#  24  minute               5000 non-null   int64
# dtypes: int64(12), object(13)
# memory usage: 976.7+ KB

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Validity
#
# Here, unecessary columns are removed. 'month' and 'year' column is also removed because the sample collected in the 9 consecutive days is from the same month and year.

# %%
#dropping columns
df.drop(['Cars','Displayed comment','Geo point','Public name','Scheduled at','year','month'],axis=1,inplace=True)
df.head(2)
# Out:
#                      Address  Bluecar counter  Utilib counter  \
# 0        2 Avenue de Suffren                0               0
# 1  145 Rue Raymond Losserand                6               0
#
#    Utilib 1.4 counter  Charge Slots Charging Status   City  \
# 0                   0             0     nonexistent  Paris
# 1                   0             0     operational  Paris
#
#                            ID     Kind  Postal code Rental status  Slots  \
# 0             paris-suffren-2  STATION        75015   operational      2
# 1  paris-raymondlosserand-145  STATION        75014   operational      0
#
#   Station type Status Subscription status  day  hour  minute
# 0      station     ok         nonexistent    8    11      43
# 1      station     ok         nonexistent    6     7      24

# %% [markdown]
# ### Accuracy
# as per the data description, charge slots can only be greater than 0 when operational. therefore checking:

# %%
#checking if charge slots are more than 0 when their status is operational  
df[~(df['Charge Slots']>0)&(df['Charging Status']=='operational')]
# Out:
#                                Address  Bluecar counter  Utilib counter  \
# 1            145 Rue Raymond Losserand                6               0
# 2     2 Avenue John Fitzgerald Kennedy                3               0
# 17              182 Boulevard Voltaire                6               0
# 19                11 avenue Ren̩ Coty                4               0
# 20                2 Place de Catalogne                3               0
# ...                                ...              ...             ...
# 4973                     18 Rue Balard                5               0
# 4989                    3 Rue Mongenot                4               0
# 4990        47 boulevard de l'H̫pital                0               0
# 4994                  15 rue de Rocroy                0               0
# 4999               5 Rue Henry Brisson                4               0
#
#       Utilib 1.4 counter  Charge Slots Charging Status          City  \
# 1                      0             0     operational         Paris
# 2                      2             0     operational    Le Bourget
# 17                     0             0     operational         Paris
# 19                     2             0     operational         Paris
# 20                     0             0     operational         Paris
# ...                  ...           ...             ...           ...
# 4973                   0             0     operational         Paris
# 4989                   0             0     operational  Saint-Mand̩
# 4990                   0             0     operational         Paris
# 4994                   0             0     operational         Paris
# 4999                   0             0     operational         Paris
#
#                                      ID     Kind  Postal code Rental status  \
# 1            paris-raymondlosserand-145  STATION        75014   operational
# 2     lebourget-johnfitzgeraldkennedy-2  STATION        93350   operational
# 17                   paris-voltaire-182  STATION        75011   operational
# 19                    paris-renecoty-11  STATION        75014   operational
# 20                    paris-catalogne-2    SPACE        75014   operational
# ...                                 ...      ...          ...           ...
# 4973                    paris-balard-18    SPACE        75015   operational
# 4989              saintmande-mongenot-3  STATION        94160   operational
# 4990                   paris-hopital-47  STATION        75013   operational
# 4994                    paris-rocroy-15  STATION        75010   operational
# 4999               paris-henrybrisson-5  STATION        75018   operational
#
#       Slots  Station type Status Subscription status  day  hour  minute
# 1         0       station     ok         nonexistent    6     7      24
# 2         1       station     ok         nonexistent    3    20      14
# 17        0       station     ok         nonexistent    9    12      14
# 19        0       station     ok         nonexistent    9    21      31
# 20        0  full_station     ok         operational    5     6      16
# ...     ...           ...    ...                 ...  ...   ...     ...
# 4973      0  full_station     ok         operational    9    13      34
# 4989      0       station     ok         nonexistent    6     7      28
# 4990      4       station     ok         nonexistent    3    21      13
# 4994      1       station     ok         nonexistent    1    20      49
# 4999      0       station     ok         nonexistent    8    10       2
#
# [1001 rows x 18 columns]

# %% [markdown]
# ### completeness
#
# as shown below,the data has no null values thus complete considering the unecessary columns were dropped

# %%
df.isnull().sum()
# Out:
# Address                0
# Bluecar counter        0
# Utilib counter         0
# Utilib 1.4 counter     0
# Charge Slots           0
# Charging Status        0
# City                   0
# ID                     0
# Kind                   0
# Postal code            0
# Rental status          0
# Slots                  0
# Station type           0
# Status                 0
# Subscription status    0
# day                    0
# hour                   0
# minute                 0
# dtype: int64

# %% [markdown]
# ### Consistency
# as shown below there are no duplicate records

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Uniformity
# The following lines of code are meant to edit the column names ensuring they are in small letters and separated by an underscore for multiple worded column names

# %%
df=df.rename(columns=str.lower)
df.head()
# Out:
#                               address  bluecar counter  utilib counter  \
# 0                 2 Avenue de Suffren                0               0
# 1           145 Rue Raymond Losserand                6               0
# 2    2 Avenue John Fitzgerald Kennedy                3               0
# 3              51 Rue Eug̬ne Oudin̩                3               1
# 4  6 avenue de la Porte de Champerret                3               0
#
#    utilib 1.4 counter  charge slots charging status        city  \
# 0                   0             0     nonexistent       Paris
# 1                   0             0     operational       Paris
# 2                   2             0     operational  Le Bourget
# 3                   0             1     operational       Paris
# 4                   0             0     nonexistent       Paris
#
#                                   id     kind  postal code rental status  \
# 0                    paris-suffren-2  STATION        75015   operational
# 1         paris-raymondlosserand-145  STATION        75014   operational
# 2  lebourget-johnfitzgeraldkennedy-2  STATION        93350   operational
# 3              paris-eugeneoudine-51  STATION        75013   operational
# 4          paris-portedechamperret-6  PARKING        75017   operational
#
#    slots station type status subscription status  day  hour  minute
# 0      2      station     ok         nonexistent    8    11      43
# 1      0      station     ok         nonexistent    6     7      24
# 2      1      station     ok         nonexistent    3    20      14
# 3      2      station     ok         nonexistent    4     4      37
# 4      3      station     ok         nonexistent    8    17      23

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
df.head(5)
# Out:
#                               address  bluecar_counter  utilib_counter  \
# 0                 2 Avenue de Suffren                0               0
# 1           145 Rue Raymond Losserand                6               0
# 2    2 Avenue John Fitzgerald Kennedy                3               0
# 3              51 Rue Eug̬ne Oudin̩                3               1
# 4  6 avenue de la Porte de Champerret                3               0
#
#    utilib_1.4_counter  charge_slots charging_status        city  \
# 0                   0             0     nonexistent       Paris
# 1                   0             0     operational       Paris
# 2                   2             0     operational  Le Bourget
# 3                   0             1     operational       Paris
# 4                   0             0     nonexistent       Paris
#
#                                   id     kind  postal_code rental_status  \
# 0                    paris-suffren-2  STATION        75015   operational
# 1         paris-raymondlosserand-145  STATION        75014   operational
# 2  lebourget-johnfitzgeraldkennedy-2  STATION        93350   operational
# 3              paris-eugeneoudine-51  STATION        75013   operational
# 4          paris-portedechamperret-6  PARKING        75017   operational
#
#    slots station_type status subscription_status  day  hour  minute
# 0      2      station     ok         nonexistent    8    11      43
# 1      0      station     ok         nonexistent    6     7      24
# 2      1      station     ok         nonexistent    3    20      14
# 3      2      station     ok         nonexistent    4     4      37
# 4      3      station     ok         nonexistent    8    17      23

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Identify the most popular hour of the day for picking up a shared electric car (Bluecar) in the city of Paris over the month of April 2018.
#
# we are assuming that the counter counts the number of cars available at the stations at that given time

# %%
df[(df['bluecar_counter'] == 0) & (df['city'] == 'Paris')]['hour'].value_counts().sort_values(ascending = False).head()
# Out:
# 2     54
# 21    52
# 3     52
# 16    50
# 23    49
# Name: hour, dtype: int64

# %% [markdown]
# ### What is the most popular hour for returning cars
#
# again assuming there are resources to count at the stations thus all resources have been returned at the given time

# %%
df[(df['bluecar_counter'] > 0) & (df['utilib_counter'] > 0) & (df['utilib_1.4_counter'] > 0)]['hour'].value_counts().head(2)
# Out:
# 14    5
# 1     5
# Name: hour, dtype: int64

# %% [markdown]
# #### most popular hour for picking cars

# %%
df[(df['bluecar_counter'] == 0) & (df['utilib_counter'] == 0) & (df['utilib_1.4_counter'] == 0)]['hour'].value_counts().head(2)
# Out:
# 14    70
# 21    67
# Name: hour, dtype: int64

# %% [markdown]
# ### What station is the most popular?
#     -Overall?

# %%
df[(df['bluecar_counter'] == 0) & (df['utilib_counter'] == 0) & (df['utilib_1.4_counter'] == 0)&(df['kind']=='STATION')]['id'].value_counts().head(1)
# Out:
# guyancourt-philibertdelorme-9    8
# Name: id, dtype: int64

# %% [markdown]
# ### What station is the most popular?
#     -At the most popular picking hour?

# %%
df[(df['hour']==14)&(df['kind']=='STATION')]['id'].value_counts().head(1)
# Out:
# paris-aumale-28    3
# Name: id, dtype: int64

# %% [markdown]
# ### What postal code is the most popular for picking up Blue cars?
# Does the most popular station belong to that postal code?

# %%
df[(df['bluecar_counter'] == 0)]['postal_code'].value_counts().head(1)
# Out:
# 75008    94
# Name: postal_code, dtype: int64

# %%
#to get the list of stations with the most popular postal code
df[df['postal_code']==75008]['id'].unique()
# Out:
# array(['paris-sainthonore-161', 'paris-courcelles-69',
#        'paris-haussmann-61', 'paris-saintaugustin-9',
#        'paris-concorde-parking', 'paris-rome-73', 'paris-berri-10',
#        'paris-malesherbes-7', 'paris-monceau-43',
#        'paris-constantinople-4', 'paris-chateaubriand-19',
#        'paris-sainthonore-422', 'paris-hoche-31', 'paris-tronchet-19',
#        'paris-courcelles-40', 'paris-batignolles-9', 'paris-liege-24',
#        'paris-matignon-2', 'paris-georgev-44', 'paris-astorg-11',
#        'paris-messine-12', 'paris-francois1er-7', 'paris-rome-46',
#        'paris-madeleinetronchet-parking', 'paris-friedland-42',
#        'paris-francois1er-38', 'paris-sainthonore-123', 'paris-artois-11',
#        'paris-pierrecharron-62', 'paris-sainthonore-91', 'paris-dutuit-1',
#        'paris-malesherbes-113', 'paris-laboetie-37'], dtype=object)

# %%
df[(df['id']=='guyancourt-philibertdelorme-9')& (df['postal_code']==75008)]
# Out:
# Empty DataFrame
# Columns: [address, bluecar_counter, utilib_counter, utilib_1.4_counter, charge_slots, charging_status, city, id, kind, postal_code, rental_status, slots, station_type, status, subscription_status, day, hour, minute]
# Index: []

# %% [markdown]
# the most popular postal code for picking up a bluecar

# %%
df[(df['bluecar_counter'] == 0)&(df['hour']==14)]['postal_code'].value_counts().head(1)
# Out:
# 75009    6
# Name: postal_code, dtype: int64

# %%
df[df['postal_code']==75009]['id'].unique()
# Out:
# array(['paris-anvers-parking', 'paris-londres-6', 'paris-rochechouart-31',
#        'paris-juleslefebvre-1', 'paris-lafayette-56',
#        'paris-adolphemax-6', 'paris-victormasse-35', 'paris-turgot-4',
#        'paris-victoire-76', 'paris-provence-35', 'paris-rochambeau-6',
#        'paris-aumale-28', 'paris-conservatoire-13', 'paris-trudaine-26',
#        'paris-chateaudun-21', 'paris-faubourgmontmartre-31',
#        'paris-haussmann-6', 'paris-clichy-23', 'paris-lafayette-7',
#        'paris-milton-12', 'paris-madeleine-8', 'paris-chausseedantin-5',
#        'paris-paulescudier-2'], dtype=object)

# %% [markdown]
# ##### checking on utilib

# %%
df[(df['utilib_counter'] == 0)&(df['hour']==14)]['postal_code'].value_counts().head(1)
# Out:
# 75015    14
# Name: postal_code, dtype: int64

# %%
df[(df['id']=='guyancourt-philibertdelorme-9')& (df['postal_code']==75015)]
# Out:
# Empty DataFrame
# Columns: [address, bluecar_counter, utilib_counter, utilib_1.4_counter, charge_slots, charging_status, city, id, kind, postal_code, rental_status, slots, station_type, status, subscription_status, day, hour, minute]
# Index: []

# %% [markdown]
# #### checking on utilib 1.4

# %%
df[(df['utilib_1.4_counter'] == 0)&(df['hour']==14)]['postal_code'].value_counts().head(1)
# Out:
# 75015    14
# Name: postal_code, dtype: int64

# %%
df[(df['id']=='guyancourt-philibertdelorme-9')& (df['postal_code']==75015)]
# Out:
# Empty DataFrame
# Columns: [address, bluecar_counter, utilib_counter, utilib_1.4_counter, charge_slots, charging_status, city, id, kind, postal_code, rental_status, slots, station_type, status, subscription_status, day, hour, minute]
# Index: []

# %%
df[(df['id']=='guyancourt-philibertdelorme-9')]['postal_code'].value_counts()
# Out:
# 78280    8
# Name: postal_code, dtype: int64

# %% [markdown]
# #### further summary

# %%
df.head()
# Out:
#                               address  bluecar_counter  utilib_counter  \
# 0                 2 Avenue de Suffren                0               0
# 1           145 Rue Raymond Losserand                6               0
# 2    2 Avenue John Fitzgerald Kennedy                3               0
# 3              51 Rue Eug̬ne Oudin̩                3               1
# 4  6 avenue de la Porte de Champerret                3               0
#
#    utilib_1.4_counter  charge_slots charging_status        city  \
# 0                   0             0     nonexistent       Paris
# 1                   0             0     operational       Paris
# 2                   2             0     operational  Le Bourget
# 3                   0             1     operational       Paris
# 4                   0             0     nonexistent       Paris
#
#                                   id     kind  postal_code rental_status  \
# 0                    paris-suffren-2  STATION        75015   operational
# 1         paris-raymondlosserand-145  STATION        75014   operational
# 2  lebourget-johnfitzgeraldkennedy-2  STATION        93350   operational
# 3              paris-eugeneoudine-51  STATION        75013   operational
# 4          paris-portedechamperret-6  PARKING        75017   operational
#
#    slots station_type status subscription_status  day  hour  minute
# 0      2      station     ok         nonexistent    8    11      43
# 1      0      station     ok         nonexistent    6     7      24
# 2      1      station     ok         nonexistent    3    20      14
# 3      2      station     ok         nonexistent    4     4      37
# 4      3      station     ok         nonexistent    8    17      23

# %% [markdown]
# to get the charging status for the stations available

# %%
df[df['kind']=='STATION']['charging_status'].value_counts()
# Out:
# nonexistent    2415
# operational    1863
# broken          110
# Name: charging_status, dtype: int64

# %%
df['station_type'].value_counts()
# Out:
# station         4615
# full_station     382
# subs_center        3
# Name: station_type, dtype: int64

# %%
df.groupby(['charge_slots'])['slots'].sum()
# Out:
# charge_slots
# 0    5851
# 1    2485
# 2    1326
# Name: slots, dtype: int64

# %% [markdown]
# ### Recommendations
# From the analysis, the above findings  would guide in a more understanding of  the behavioural patterns concerning the electric car sharing service in terms of popularity in the stations and periods in a typical day
